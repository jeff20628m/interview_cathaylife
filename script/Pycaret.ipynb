# %%
from pycaret.classification import *
# Out:
# In C:\Users\USER\Anaconda3\Lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\USER\Anaconda3\Lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\USER\Anaconda3\Lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\USER\Anaconda3\Lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
from preprocessing import preprocessing_training , preprocessing_testing
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('../data/train.csv')
x_train,x_test,y_train,y_test = train_test_split(train,train['Response'],test_size=0.1,random_state=26)

# %%
pre_train = preprocessing_training(x_train)

df, map_list = pre_train.preprocessing()

pre_test = preprocessing_testing(x_test, map_list[0], map_list[1],
                                 map_list[2], map_list[3])

df_test = pre_test.preprocessing()

df_test = df_test.drop(['id', 'Vehicle_Damage'], axis=1)

df = df.drop(['id', 'Vehicle_Damage'], axis=1)
# Out:
# Drop Vehicle_Age type object
# Drop Age_group type category
# There's non label data!
# Drop Vehicle_Age type object
# Drop Age_group type category

# %%
train = pd.read_csv('../data/train.csv') 
test = pd.read_csv('../data/test.csv')

# %%
exp_name = setup(data = df,  target = 'Response')
# Out:
# <style  type="text/css" >
# </style><table id="T_85377558_d115_11eb_bc8b_b42e994028ea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85377558_d115_11eb_bc8b_b42e994028ealevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_85377558_d115_11eb_bc8b_b42e994028earow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_85377558_d115_11eb_bc8b_b42e994028earow0_col1" class="data row0 col1" >4809</td>
#             </tr>
#             <tr>
#                         <th id="T_85377558_d115_11eb_bc8b_b42e994028ealevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_85377558_d115_11eb_bc8b_b42e994028earow1_col0" class="data row1 col0" >Target</td>
# ...

# %%
#get_config('fix_imbalance_method_param')

# %%
set_config('fold_param',5)
#set_config('fix_imbalance_param',True)

# %%
top3 = compare_models(n_select = 3)
tuned_top3 = [tune_model(i) for i in top3]
blender = blend_models(tuned_top3)
#stacker = stack_models(tuned_top5)
#best_auc_model = automl(optimize = 'AUC')
# Out:
# IntProgress(value=0, description='Processing: ', max=79)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             23:46:51
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
# <style  type="text/css" >
#     #T_4896b612_d116_11eb_a5b5_b42e994028ea th {
#           text-align: left;
#     }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col0 {
#             text-align:  left;
#         }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col1 {
#             text-align:  left;
#         }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col2 {
#             text-align:  left;
#         }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col3 {
#             text-align:  left;
#         }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col4 {
#             text-align:  left;
#         }    #T_4896b612_d116_11eb_a5b5_b42e994028earow0_col5 {
#             text-align:  left;
# ...
